# %%
# !git clone https://github.com/ZhuHuoChiMao/nlp_rag.git
# %cd nlp_rag
# !ls
# Out:
# Cloning into 'nlp_rag'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 138 (delta 46), reused 132 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (138/138), 806.34 KiB | 10.47 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/nlp_rag/nlp_rag/nlp_rag
# ajouer_docid.py  data		   dsdads.txt  rag_local.py
# clean.py	 data_with_doc_id  rag_index   requirements.txt

# %%
# !pip -q install -r requirements.txt

# %%
from huggingface_hub import login
login()

# %%
# !python rag_local.py --rebuild
# Out:
# 2026-01-30 12:43:21.037790: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769777001.100137   20549 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769777001.111606   20549 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769777001.146553   20549 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
